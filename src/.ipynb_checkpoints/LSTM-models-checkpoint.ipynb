# %% [markdown]
# # Long Short Time Memory
#
# Table of contents
# 1. [Library imports](#Library-imports)
# 2. [Data Reading](#Data-reading)
#     1. [Data cleaning](#Data-cleaning)
#     2. [Data normalizarion](#Data-normalization)
# 3. [LSTM](#LSTM-models-fitting)
#     1. [Fine tuning](#Fine-tuning)
#     2. [Final model](#Final-model)
#
# ## Library imports

# %%
# !pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow>=2.8.0 in /home/valcarce/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: pandas>=1.3.3 in /home/valcarce/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/valcarce/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 3)) (1.22.2)
# Requirement already satisfied: pytz>=2020.1 in /home/valcarce/.local/lib/python3.10/site-packages (from pandas>=1.3.3->-r ../requirements.txt (line 2)) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/lib/python3.10/site-packages (from pandas>=1.3.3->-r ../requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (1.13.3)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (2.8.0.dev2021122109)
# Requirement already satisfied: libclang>=9.0.1 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (13.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: absl-py>=0.4.0 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: setuptools in /usr/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (59.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (1.44.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: flatbuffers>=1.12 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (0.24.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (3.19.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/valcarce/.local/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/lib/python3.10/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3.10/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/valcarce/.local/lib/python3.10/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/valcarce/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/valcarce/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/valcarce/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/valcarce/.local/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/valcarce/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: chardet>=3.0.2 in /usr/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: idna>=2.5 in /usr/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (3.3)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (1.26.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/valcarce/.local/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->-r ../requirements.txt (line 1)) (3.2.0)

# %%
from utils.utils import mix_data, generate_windows # custom functions
import tensorflow as tf                            # LSTM
import pandas as pd                                # DataFrames
import numpy as np                                 # Vectorial computation
import itertools                                   # Combinatory
import datetime                                    # Dates formatting
# Out:
# 2022-03-01 21:04:10.610277: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-01 21:04:10.610300: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Data reading

# %%
df = pd.read_csv('../data/radon-data.csv')   # CSV reading
df.head()
# Out:
#       id        time  radon  temperature  humidity  pressure  tvoc  sensor_id  \
# 0  21906  1569405062    202           25        50      1015     0          2
# 1  21907  1569405663    258           25        51      1015     0          2
# 2  21908  1569406264    202           24        51      1015     0          2
# 3  21909  1569406865    182           24        51      1015     0          2
# 4  21910  1569407466    189           24        51      1015     0          2
#
#   state  state_time
# 0   Off  1569404979
# 1    On  1569405215
# 2   Off  1569405671
# 3   Off  1569406848
# 4   Off  1569406866

# %% [markdown]
# ### Data cleaning

# %%
# Now we will parse the data, so it is usable
df.time = pd.to_datetime(df['time'], unit='s', origin='unix')      # date parse
df = df.drop(columns = ["time", "id", "sensor_id", "state_time"])  # drop useless columns
df.state = (df.state == "On").astype(int)                          # binarize state
df.head()
# Out:
#    radon  temperature  humidity  pressure  tvoc  state
# 0    202           25        50      1015     0      0
# 1    258           25        51      1015     0      1
# 2    202           24        51      1015     0      0
# 3    182           24        51      1015     0      0
# 4    189           24        51      1015     0      0

# %%
# we now select the data from the summer (longest clean data)
df_summer = df.iloc[36000:48000]
df_summer.head()
# Out:
#        radon  temperature  humidity  pressure  tvoc  state
# 36000    388           24        57      1010     4      1
# 36001    383           24        57      1010     2      1
# 36002    398           24        57      1010     6      1
# 36003    388           24        57      1010     8      1
# 36004    388           24        57      1010    10      1

# %% [markdown]
# ### Data normalization

# %%
summer_min = df_summer.min() # needed to de-normalize data
summer_max = df_summer.max()

df_summer_normalized = (df_summer - summer_min) / (summer_max - summer_min)
df_summer_normalized.head()
# Out:
#           radon  temperature  humidity  pressure      tvoc  state
# 36000  0.119640     0.714286  0.666667       0.5  0.003463    1.0
# 36001  0.117911     0.714286  0.666667       0.5  0.001732    1.0
# 36002  0.123098     0.714286  0.666667       0.5  0.005195    1.0
# 36003  0.119640     0.714286  0.666667       0.5  0.006926    1.0
# 36004  0.119640     0.714286  0.666667       0.5  0.008658    1.0

# %% [markdown]
# ## LSTM models fitting

# %%
# We will use early stopping to select the best model
callback = tf.keras.callbacks.EarlyStopping(
    monitor              = 'val_loss',
    patience             = 30,
    restore_best_weights = True
)

# percentage of train samples
train_pct = 0.9

# We will store all the results in a data frame
results = pd.DataFrame(
    {i: [None]*15 for i in [1, 5, 10, 15, 25]}
)

cnt = 0 # helps counting

for number_of_covariates in range(4):
    for covariate_combination in itertools.combinations(("state", "humidity", "pressure", "tvoc"), 
                                                        number_of_covariates):
        print(f"EXECUTING OVER: {covariate_combination}".center(100, "*"))
        # We compute for each window size
        for window_size in [1, 5, 10, 15, 25]:
            print("\n")
            print(f"EXECUTING {window_size} WINDOW SIZE".center(100), "-")
            print("\n")
            windows = {i: generate_windows(df_summer_normalized[i], window_size, 1)
                        for i in ["radon"] + list(covariate_combination) }
            
            print("Windows computed, now building the model")
            
            data = mix_data(windows)
            N_total          = data.shape[0]
            test             = data[int(train_pct * N_total):, :, :]
            data             = data[:int(train_pct * N_total), :, :]
            
            model = tf.keras.models.Sequential(
                [
                    tf.keras.layers.InputLayer((window_size, len(windows.keys()))),
                    tf.keras.layers.LSTM(window_size * 2),
                    tf.keras.layers.Dense(16, activation = "relu"),
                    tf.keras.layers.Dense(16, activation = "relu"),
                    tf.keras.layers.Dense(1)
                ],
            )
            
            model.compile(
                loss = tf.keras.losses.MeanSquaredError(),
                metrics = tf.keras.metrics.RootMeanSquaredError(),
                optimizer = tf.keras.optimizers.RMSprop()
            )
            
            model.summary()
            
            model.fit(
                x                = data[:, :window_size, :],
                y                = data[:, window_size:, 0],
                epochs           = 1_000,
                shuffle          = False,
                validation_split = 0.2, 
                callbacks        = [callback,],
                verbose          = 0,
            )
            
            # Model trained
            
            # Now compute the test predictions and add them to the data frame
            rescale    = lambda x: x * (summer_max.radon - summer_min.radon) + summer_min.radon
            prediction = rescale( model.predict(test[:, :window_size, :]) )
            real       = rescale( test[:, window_size:, 0] )
            
            rmse_test = ( sum((prediction - real) ** 2) / len(prediction) ) ** (1/2)
            results[window_size][cnt] = rmse_test 
            print(f"Window {window_size}, covariates {covariate_combination}: {results[window_size][cnt]}")
        cnt += 1    
        print("*" * 100, "\n"*2)

# %% [markdown]
# ### Fine tuning
# Once we know what model behaves the best, we try to explode this configuration.

# %%
# We will use early stopping to select the best model
callback = tf.keras.callbacks.EarlyStopping(
    monitor              = 'val_loss',
    patience             = 30,
    restore_best_weights = True
)

# percentage of train samples
train_pct = 0.9

# We will store all the results in a data frame
results = pd.DataFrame(
    {i: [None]*4 for i in [4, 8, 16, 32]}
)

# dense configurations:
dense_combination_config = [[16], [16, 16], [32], [32, 32]]

window_size = 15

# we do not need to create the data in a loop:
windows = {i: generate_windows(df_summer_normalized[i], window_size, 1)
                for i in ["radon", "state"] }
data    = mix_data(windows)
N_total = data.shape[0]
test    = data[int(train_pct * N_total):, :, :]
data    = data[:int(train_pct * N_total), :, :]

for idx, dense_config in enumerate(dense_combination_config):
    for num_hidden_units in [4, 8, 16, 32]:
        
        model = tf.keras.models.Sequential(
            [
                tf.keras.layers.InputLayer((window_size, len(windows.keys()))),
                tf.keras.layers.LSTM(num_hidden_units),
                *[tf.keras.layers.Dense(i, activation = "relu") for i in dense_config],
                tf.keras.layers.Dense(1)
            ],
        )

        model.compile(
            loss = tf.keras.losses.MeanSquaredError(),
            metrics = tf.keras.metrics.RootMeanSquaredError(),
            optimizer = tf.keras.optimizers.RMSprop()
        )

        model.summary()

        model.fit(
            x                = data[:, :window_size, :],
            y                = data[:, window_size:, 0],
            epochs           = 1_000,
            shuffle          = False,
            validation_split = 0.2, 
            callbacks        = [callback,],
            verbose          = 0,
        )

        # Model trained

        # Now compute the test predictions and add them to the data frame
        rescale    = lambda x: x * (summer_max.radon - summer_min.radon) + summer_min.radon
        prediction = rescale( model.predict(test[:, :window_size, :]) )
        real       = rescale( test[:, window_size:, 0] )

        rmse_test = ( sum((prediction - real) ** 2) / len(prediction) ) ** (1/2)
        results[num_hidden_units][idx] = rmse_test 
        print(f"Config {idx} with {num_hidden_units} hidden units -> {rmse_test}")
        print("*" * 100, "\n"*2)

# %% [markdown]
# ## Final model

# %%
# We will use early stopping to select the best model
callback = tf.keras.callbacks.EarlyStopping(
    monitor              = 'val_loss',
    patience             = 30,
    restore_best_weights = True
)

# percentage of train samples
train_pct = 0.9

window_size = 15

# we do not need to create the data in a loop:
windows = {i: generate_windows(df_summer_normalized[i], window_size, 1)
                for i in ["radon", "state"] }
data    = mix_data(windows)
N_total = data.shape[0]
test    = data[int(train_pct * N_total):, :, :]
data    = data[:int(train_pct * N_total), :, :]

model = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((window_size, len(windows.keys()))),
        tf.keras.layers.LSTM(15),
        tf.keras.layers.Dense(32, activation = "relu"),
        tf.keras.layers.Dense(1)
    ],
)

model.compile(
    loss = tf.keras.losses.MeanSquaredError(),
    metrics = tf.keras.metrics.RootMeanSquaredError(),
    optimizer = tf.keras.optimizers.RMSprop()
)

model.summary()

model.fit(
    x                = data[:, :window_size, :],
    y                = data[:, window_size:, 0],
    epochs           = 1_000,
    shuffle          = False,
    validation_split = 0.2, 
    callbacks        = [callback,],
)

# Model trained

# Now compute the test predictions and add them to the data frame
rescale    = lambda x: x * (summer_max.radon - summer_min.radon) + summer_min.radon
prediction = rescale( model.predict(test[:, :window_size, :]) )
real       = rescale( test[:, window_size:, 0] )

rmse_test = ( sum((prediction - real) ** 2) / len(prediction) ) ** (1/2)
print(f"RMSE -> {rmse_test}")
# Out:
# 2022-03-01 21:04:29.928856: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-01 21:04:29.928905: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-01 21:04:29.928938: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (satira): /proc/driver/nvidia/version does not exist
# 2022-03-01 21:04:29.929318: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 15)                1080
#
#  dense (Dense)               (None, 32)                512
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,625
# Trainable params: 1,625
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 270/270 [==============================] - 4s 11ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 2.7452e-04 - val_root_mean_squared_error: 0.0166
# Epoch 2/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 0.0031 - root_mean_squared_error: 0.0555 - val_loss: 2.2656e-04 - val_root_mean_squared_error: 0.0151
# Epoch 3/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 0.0023 - root_mean_squared_error: 0.0481 - val_loss: 1.9798e-04 - val_root_mean_squared_error: 0.0141
# Epoch 4/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 0.0016 - root_mean_squared_error: 0.0402 - val_loss: 1.7440e-04 - val_root_mean_squared_error: 0.0132
# Epoch 5/1000
# 270/270 [==============================] - 2s 8ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 1.5611e-04 - val_root_mean_squared_error: 0.0125
# Epoch 6/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.7155e-04 - root_mean_squared_error: 0.0259 - val_loss: 1.4309e-04 - val_root_mean_squared_error: 0.0120
# Epoch 7/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 4.1911e-04 - root_mean_squared_error: 0.0205 - val_loss: 1.3296e-04 - val_root_mean_squared_error: 0.0115
# Epoch 8/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 2.7298e-04 - root_mean_squared_error: 0.0165 - val_loss: 1.2692e-04 - val_root_mean_squared_error: 0.0113
# Epoch 9/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 2.0271e-04 - root_mean_squared_error: 0.0142 - val_loss: 1.2137e-04 - val_root_mean_squared_error: 0.0110
# Epoch 10/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 1.6484e-04 - root_mean_squared_error: 0.0128 - val_loss: 1.1417e-04 - val_root_mean_squared_error: 0.0107
# Epoch 11/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 1.4560e-04 - root_mean_squared_error: 0.0121 - val_loss: 1.0494e-04 - val_root_mean_squared_error: 0.0102
# Epoch 12/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 1.3308e-04 - root_mean_squared_error: 0.0115 - val_loss: 9.4737e-05 - val_root_mean_squared_error: 0.0097
# Epoch 13/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 1.2330e-04 - root_mean_squared_error: 0.0111 - val_loss: 8.6193e-05 - val_root_mean_squared_error: 0.0093
# Epoch 14/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 1.1603e-04 - root_mean_squared_error: 0.0108 - val_loss: 7.8626e-05 - val_root_mean_squared_error: 0.0089
# Epoch 15/1000
# 270/270 [==============================] - 3s 11ms/step - loss: 1.1027e-04 - root_mean_squared_error: 0.0105 - val_loss: 7.1055e-05 - val_root_mean_squared_error: 0.0084
# Epoch 16/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 1.0463e-04 - root_mean_squared_error: 0.0102 - val_loss: 6.4388e-05 - val_root_mean_squared_error: 0.0080
# Epoch 17/1000
# 270/270 [==============================] - 2s 8ms/step - loss: 9.8293e-05 - root_mean_squared_error: 0.0099 - val_loss: 5.9912e-05 - val_root_mean_squared_error: 0.0077
# Epoch 18/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 9.7254e-05 - root_mean_squared_error: 0.0099 - val_loss: 5.5449e-05 - val_root_mean_squared_error: 0.0074
# Epoch 19/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 9.0263e-05 - root_mean_squared_error: 0.0095 - val_loss: 5.3581e-05 - val_root_mean_squared_error: 0.0073
# Epoch 20/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 7.3079e-05 - root_mean_squared_error: 0.0085 - val_loss: 5.1433e-05 - val_root_mean_squared_error: 0.0072
# Epoch 21/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 7.6002e-05 - root_mean_squared_error: 0.0087 - val_loss: 4.7925e-05 - val_root_mean_squared_error: 0.0069
# Epoch 22/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 7.1314e-05 - root_mean_squared_error: 0.0084 - val_loss: 4.6014e-05 - val_root_mean_squared_error: 0.0068
# Epoch 23/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 6.7417e-05 - root_mean_squared_error: 0.0082 - val_loss: 4.4605e-05 - val_root_mean_squared_error: 0.0067
# Epoch 24/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 6.4164e-05 - root_mean_squared_error: 0.0080 - val_loss: 4.3472e-05 - val_root_mean_squared_error: 0.0066
# Epoch 25/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.1783e-05 - root_mean_squared_error: 0.0079 - val_loss: 4.2594e-05 - val_root_mean_squared_error: 0.0065
# Epoch 26/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.0203e-05 - root_mean_squared_error: 0.0078 - val_loss: 4.2121e-05 - val_root_mean_squared_error: 0.0065
# Epoch 27/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.8693e-05 - root_mean_squared_error: 0.0077 - val_loss: 4.1632e-05 - val_root_mean_squared_error: 0.0065
# Epoch 28/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.7056e-05 - root_mean_squared_error: 0.0076 - val_loss: 4.1363e-05 - val_root_mean_squared_error: 0.0064
# Epoch 29/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.5939e-05 - root_mean_squared_error: 0.0075 - val_loss: 4.0685e-05 - val_root_mean_squared_error: 0.0064
# Epoch 30/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 5.4828e-05 - root_mean_squared_error: 0.0074 - val_loss: 4.0462e-05 - val_root_mean_squared_error: 0.0064
# Epoch 31/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 5.4010e-05 - root_mean_squared_error: 0.0073 - val_loss: 4.0415e-05 - val_root_mean_squared_error: 0.0064
# Epoch 32/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 5.3032e-05 - root_mean_squared_error: 0.0073 - val_loss: 3.9963e-05 - val_root_mean_squared_error: 0.0063
# Epoch 33/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.2226e-05 - root_mean_squared_error: 0.0072 - val_loss: 3.9851e-05 - val_root_mean_squared_error: 0.0063
# Epoch 34/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 5.1484e-05 - root_mean_squared_error: 0.0072 - val_loss: 3.9525e-05 - val_root_mean_squared_error: 0.0063
# Epoch 35/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.0749e-05 - root_mean_squared_error: 0.0071 - val_loss: 3.9416e-05 - val_root_mean_squared_error: 0.0063
# Epoch 36/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.0147e-05 - root_mean_squared_error: 0.0071 - val_loss: 3.9262e-05 - val_root_mean_squared_error: 0.0063
# Epoch 37/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 4.9384e-05 - root_mean_squared_error: 0.0070 - val_loss: 3.9100e-05 - val_root_mean_squared_error: 0.0063
# Epoch 38/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 4.8779e-05 - root_mean_squared_error: 0.0070 - val_loss: 3.8973e-05 - val_root_mean_squared_error: 0.0062
# Epoch 39/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 4.8110e-05 - root_mean_squared_error: 0.0069 - val_loss: 3.8878e-05 - val_root_mean_squared_error: 0.0062
# Epoch 40/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.7773e-05 - root_mean_squared_error: 0.0069 - val_loss: 3.8667e-05 - val_root_mean_squared_error: 0.0062
# Epoch 41/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 4.7093e-05 - root_mean_squared_error: 0.0069 - val_loss: 3.8538e-05 - val_root_mean_squared_error: 0.0062
# Epoch 42/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.6622e-05 - root_mean_squared_error: 0.0068 - val_loss: 3.8468e-05 - val_root_mean_squared_error: 0.0062
# Epoch 43/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.6251e-05 - root_mean_squared_error: 0.0068 - val_loss: 3.8273e-05 - val_root_mean_squared_error: 0.0062
# Epoch 44/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.5947e-05 - root_mean_squared_error: 0.0068 - val_loss: 3.8094e-05 - val_root_mean_squared_error: 0.0062
# Epoch 45/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.5540e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.8146e-05 - val_root_mean_squared_error: 0.0062
# Epoch 46/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.5378e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.8063e-05 - val_root_mean_squared_error: 0.0062
# Epoch 47/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.5063e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.7931e-05 - val_root_mean_squared_error: 0.0062
# Epoch 48/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.5011e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.7913e-05 - val_root_mean_squared_error: 0.0062
# Epoch 49/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.4511e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.7727e-05 - val_root_mean_squared_error: 0.0061
# Epoch 50/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 4.4629e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.7998e-05 - val_root_mean_squared_error: 0.0062
# Epoch 51/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 4.4471e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.7607e-05 - val_root_mean_squared_error: 0.0061
# Epoch 52/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.4256e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.7487e-05 - val_root_mean_squared_error: 0.0061
# Epoch 53/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.4179e-05 - root_mean_squared_error: 0.0066 - val_loss: 3.7577e-05 - val_root_mean_squared_error: 0.0061
# Epoch 54/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 4.4325e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.7404e-05 - val_root_mean_squared_error: 0.0061
# Epoch 55/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 4.4478e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.7516e-05 - val_root_mean_squared_error: 0.0061
# Epoch 56/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 4.5017e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.7514e-05 - val_root_mean_squared_error: 0.0061
# Epoch 57/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 4.5170e-05 - root_mean_squared_error: 0.0067 - val_loss: 3.7435e-05 - val_root_mean_squared_error: 0.0061
# Epoch 58/1000
# 270/270 [==============================] - 2s 9ms/step - loss: 7.4677e-05 - root_mean_squared_error: 0.0086 - val_loss: 3.7823e-05 - val_root_mean_squared_error: 0.0062
# Epoch 59/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 6.8464e-05 - root_mean_squared_error: 0.0083 - val_loss: 3.7599e-05 - val_root_mean_squared_error: 0.0061
# Epoch 60/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 7.1221e-05 - root_mean_squared_error: 0.0084 - val_loss: 3.7750e-05 - val_root_mean_squared_error: 0.0061
# Epoch 61/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.5140e-05 - root_mean_squared_error: 0.0081 - val_loss: 3.7745e-05 - val_root_mean_squared_error: 0.0061
# Epoch 62/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.5301e-05 - root_mean_squared_error: 0.0081 - val_loss: 3.7774e-05 - val_root_mean_squared_error: 0.0061
# Epoch 63/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.0819e-05 - root_mean_squared_error: 0.0078 - val_loss: 3.7752e-05 - val_root_mean_squared_error: 0.0061
# Epoch 64/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.0023e-05 - root_mean_squared_error: 0.0077 - val_loss: 3.7861e-05 - val_root_mean_squared_error: 0.0062
# Epoch 65/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.9972e-05 - root_mean_squared_error: 0.0077 - val_loss: 3.7787e-05 - val_root_mean_squared_error: 0.0061
# Epoch 66/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.5819e-05 - root_mean_squared_error: 0.0075 - val_loss: 3.8108e-05 - val_root_mean_squared_error: 0.0062
# Epoch 67/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.5997e-05 - root_mean_squared_error: 0.0075 - val_loss: 3.8106e-05 - val_root_mean_squared_error: 0.0062
# Epoch 68/1000
# 270/270 [==============================] - 3s 9ms/step - loss: 5.7257e-05 - root_mean_squared_error: 0.0076 - val_loss: 3.8026e-05 - val_root_mean_squared_error: 0.0062
# Epoch 69/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.5823e-05 - root_mean_squared_error: 0.0075 - val_loss: 3.8224e-05 - val_root_mean_squared_error: 0.0062
# Epoch 70/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.6863e-05 - root_mean_squared_error: 0.0075 - val_loss: 3.8025e-05 - val_root_mean_squared_error: 0.0062
# Epoch 71/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.5115e-05 - root_mean_squared_error: 0.0074 - val_loss: 3.8023e-05 - val_root_mean_squared_error: 0.0062
# Epoch 72/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.9576e-05 - root_mean_squared_error: 0.0077 - val_loss: 3.7638e-05 - val_root_mean_squared_error: 0.0061
# Epoch 73/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.4152e-05 - root_mean_squared_error: 0.0074 - val_loss: 3.8047e-05 - val_root_mean_squared_error: 0.0062
# Epoch 74/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.6984e-05 - root_mean_squared_error: 0.0075 - val_loss: 3.8110e-05 - val_root_mean_squared_error: 0.0062
# Epoch 75/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.8657e-05 - root_mean_squared_error: 0.0077 - val_loss: 3.8036e-05 - val_root_mean_squared_error: 0.0062
# Epoch 76/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.6970e-05 - root_mean_squared_error: 0.0075 - val_loss: 3.7854e-05 - val_root_mean_squared_error: 0.0062
# Epoch 77/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.8025e-05 - root_mean_squared_error: 0.0076 - val_loss: 3.7809e-05 - val_root_mean_squared_error: 0.0061
# Epoch 78/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.2830e-05 - root_mean_squared_error: 0.0079 - val_loss: 3.7855e-05 - val_root_mean_squared_error: 0.0062
# Epoch 79/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.0456e-05 - root_mean_squared_error: 0.0078 - val_loss: 3.7951e-05 - val_root_mean_squared_error: 0.0062
# Epoch 80/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.2286e-05 - root_mean_squared_error: 0.0079 - val_loss: 3.8183e-05 - val_root_mean_squared_error: 0.0062
# Epoch 81/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.7059e-05 - root_mean_squared_error: 0.0076 - val_loss: 3.8456e-05 - val_root_mean_squared_error: 0.0062
# Epoch 82/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.0524e-05 - root_mean_squared_error: 0.0078 - val_loss: 3.8278e-05 - val_root_mean_squared_error: 0.0062
# Epoch 83/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 5.7869e-05 - root_mean_squared_error: 0.0076 - val_loss: 3.8532e-05 - val_root_mean_squared_error: 0.0062
# Epoch 84/1000
# 270/270 [==============================] - 3s 10ms/step - loss: 6.1662e-05 - root_mean_squared_error: 0.0079 - val_loss: 3.8302e-05 - val_root_mean_squared_error: 0.0062
# RMSE -> [15.46663907]

# %%
model.save("../output/radon.h5", save_format = "h5")

# %%
model.save("../output/radon.pb", save_format = "tf")

# %%
summer_min, summer_max

# %%
pd.DataFrame(
    {
        "predictions": prediction.flatten(),
        "real": real.flatten(),
    }
).to_csv("../data/predictions.csv", index = False)
