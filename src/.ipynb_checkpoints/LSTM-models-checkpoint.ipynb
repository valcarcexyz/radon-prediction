# %% [markdown]
# # Long Short Time Memory
#
# Table of contents
# 1. [Library imports](#Library-imports)
# 2. [Data Reading](#Data-reading)
#     1. [Data cleaning](#Data-cleaning)
#     2. [Data normalizarion](#Data-normalization)
# 3. [LSTM](#LSTM-models-fitting)
#     1. [Fine tuning](#Fine-tuning)
# ## Library imports

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: tensorflow==2.6.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: pandas==1.3.3 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: numpy==1.19.5 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 3)) (1.19.5)
# Requirement already satisfied: wheel~=0.35 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: keras~=2.6 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (1.12.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (3.19.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: clang~=5.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (5.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (1.12)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (1.41.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.6.0->-r requirements.txt (line 1)) (2.7.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from pandas==1.3.3->-r requirements.txt (line 2)) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from pandas==1.3.3->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (2.26.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (57.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (3.3.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (1.26.6)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dvalc\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.6.0->-r requirements.txt (line 1)) (3.1.1)
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\dvalc\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
from utils.utils import mix_data, generate_windows # custom functions
import tensorflow as tf                            # LSTM
import pandas as pd                                # DataFrames
import numpy as np                                 # Vectorial computation
import itertools                                   # Combinatory
import datetime                                    # Dates formatting
# version checking
print(f"""
Tensorflow version -> {tf.__version__}
Pandas version     -> {pd.__version__}
Numpy version      -> {np.__version__}
""")
# Out:
# Tensorflow version -> 2.6.0
# Pandas version     -> 1.3.3
# Numpy version      -> 1.19.5

# %% [markdown]
# ## Data reading

# %%
df = pd.read_csv('../data/radon-data.csv')   # CSV reading
df.head()
# Out:
#       id        time  radon  temperature  humidity  pressure  tvoc  sensor_id  \
# 0  21906  1569405062    202           25        50      1015     0          2
# 1  21907  1569405663    258           25        51      1015     0          2
# 2  21908  1569406264    202           24        51      1015     0          2
# 3  21909  1569406865    182           24        51      1015     0          2
# 4  21910  1569407466    189           24        51      1015     0          2
#
#   state  state_time
# 0   Off  1569404979
# 1    On  1569405215
# 2   Off  1569405671
# 3   Off  1569406848
# 4   Off  1569406866

# %% [markdown]
# ### Data cleaning

# %%
# Now we will parse the data, so it is usable
df.time = pd.to_datetime(df['time'], unit='s', origin='unix')      # date parse
df = df.drop(columns = ["time", "id", "sensor_id", "state_time"])  # drop useless columns
df.state = (df.state == "On").astype(int)                          # binarize state
df.head()
# Out:
#    radon  temperature  humidity  pressure  tvoc  state
# 0    202           25        50      1015     0      0
# 1    258           25        51      1015     0      1
# 2    202           24        51      1015     0      0
# 3    182           24        51      1015     0      0
# 4    189           24        51      1015     0      0

# %%
# we now select the data from the summer (longest clean data)
df_summer = df.iloc[36000:48000]
df_summer.head()
# Out:
#        radon  temperature  humidity  pressure  tvoc  state
# 36000    388           24        57      1010     4      1
# 36001    383           24        57      1010     2      1
# 36002    398           24        57      1010     6      1
# 36003    388           24        57      1010     8      1
# 36004    388           24        57      1010    10      1

# %% [markdown]
# ### Data normalization

# %%
summer_min = df_summer.min() # needed to de-normalize data
summer_max = df_summer.max()

df_summer_normalized = (df_summer - summer_min) / (summer_max - summer_min)
df_summer_normalized.head()
# Out:
#           radon  temperature  humidity  pressure      tvoc  state
# 36000  0.119640     0.714286  0.666667       0.5  0.003463    1.0
# 36001  0.117911     0.714286  0.666667       0.5  0.001732    1.0
# 36002  0.123098     0.714286  0.666667       0.5  0.005195    1.0
# 36003  0.119640     0.714286  0.666667       0.5  0.006926    1.0
# 36004  0.119640     0.714286  0.666667       0.5  0.008658    1.0

# %% [markdown]
# ## LSTM models fitting

# %%
# We will use early stopping to select the best model
callback = tf.keras.callbacks.EarlyStopping(
    monitor              = 'val_loss',
    patience             = 30,
    restore_best_weights = True
)

# percentage of train samples
train_pct = 0.9

# We will store all the results in a data frame
results = pd.DataFrame(
    {i: [None]*15 for i in [1, 5, 10, 15, 25]}
)

cnt = 0 # helps counting

for number_of_covariates in range(4):
    for covariate_combination in itertools.combinations(("state", "humidity", "pressure", "tvoc"), 
                                                        number_of_covariates):
        print(f"EXECUTING OVER: {covariate_combination}".center(100, "*"))
        # We compute for each window size
        for window_size in [1, 5, 10, 15, 25]:
            print("\n")
            print(f"EXECUTING {window_size} WINDOW SIZE".center(100), "-")
            print("\n")
            windows = {i: generate_windows(df_summer_normalized[i], window_size, 1)
                        for i in ["radon"] + list(covariate_combination) }
            
            print("Windows computed, now building the model")
            
            data = mix_data(windows)
            N_total          = data.shape[0]
            test             = data[int(train_pct * N_total):, :, :]
            data             = data[:int(train_pct * N_total), :, :]
            
            model = tf.keras.models.Sequential(
                [
                    tf.keras.layers.InputLayer((window_size, len(windows.keys()))),
                    tf.keras.layers.LSTM(window_size * 2),
                    tf.keras.layers.Dense(16, activation = "relu"),
                    tf.keras.layers.Dense(16, activation = "relu"),
                    tf.keras.layers.Dense(1)
                ],
            )
            
            model.compile(
                loss = tf.keras.losses.MeanSquaredError(),
                metrics = tf.keras.metrics.RootMeanSquaredError(),
                optimizer = tf.keras.optimizers.RMSprop()
            )
            
            model.summary()
            
            model.fit(
                x                = data[:, :window_size, :],
                y                = data[:, window_size:, 0],
                epochs           = 1_000,
                shuffle          = False,
                validation_split = 0.2, 
                callbacks        = [callback,],
                verbose          = 0,
            )
            
            # Model trained
            
            # Now compute the test predictions and add them to the data frame
            rescale    = lambda x: x * (summer_max.radon - summer_min.radon) + summer_min.radon
            prediction = rescale( model.predict(test[:, :window_size, :]) )
            real       = rescale( test[:, window_size:, 0] )
            
            rmse_test = ( sum((prediction - real) ** 2) / len(prediction) ) ** (1/2)
            results[window_size][cnt] = rmse_test 
            print(f"Window {window_size}, covariates {covariate_combination}: {results[window_size][cnt]}")
        cnt += 1    
        print("*" * 100, "\n"*2)
# Out:
# *****************************************EXECUTING OVER: ()*****************************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 2)                 32
# _________________________________________________________________
# dense (Dense)                (None, 16)                48
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 369
# Trainable params: 369
# Non-trainable params: 0
# _________________________________________________________________
# Window 1, covariates (): [22.85412452]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 10)                480
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                176
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 945
# Trainable params: 945
# Non-trainable params: 0
# _________________________________________________________________
# Window 5, covariates (): [18.24357422]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 20)                1760
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                336
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 2,385
# Trainable params: 2,385
# Non-trainable params: 0
# _________________________________________________________________
# Window 10, covariates (): [16.68427226]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 30)                3840
# _________________________________________________________________
# dense_9 (Dense)              (None, 16)                496
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 4,625
# Trainable params: 4,625
# Non-trainable params: 0
# _________________________________________________________________
# Window 15, covariates (): [16.15729464]
# ****************************************************************************************************
#
#
# *************************************EXECUTING OVER: ('state',)*************************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 2)                 40
# _________________________________________________________________
# dense_12 (Dense)             (None, 16)                48
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 377
# Trainable params: 377
# Non-trainable params: 0
# _________________________________________________________________
# Window 1, covariates ('state',): [25.41163105]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 10)                520
# _________________________________________________________________
# dense_15 (Dense)             (None, 16)                176
# _________________________________________________________________
# dense_16 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 985
# Trainable params: 985
# Non-trainable params: 0
# _________________________________________________________________
# Window 5, covariates ('state',): [20.23190834]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 20)                1840
# _________________________________________________________________
# dense_18 (Dense)             (None, 16)                336
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 2,465
# Trainable params: 2,465
# Non-trainable params: 0
# _________________________________________________________________
# Window 10, covariates ('state',): [19.1116488]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 30)                3960
# _________________________________________________________________
# dense_21 (Dense)             (None, 16)                496
# _________________________________________________________________
# dense_22 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 4,745
# Trainable params: 4,745
# Non-trainable params: 0
# _________________________________________________________________
# Window 15, covariates ('state',): [16.63739721]
# ****************************************************************************************************
#
#
# ***********************************EXECUTING OVER: ('humidity',)************************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 2)                 40
# _________________________________________________________________
# dense_24 (Dense)             (None, 16)                48
# _________________________________________________________________
# dense_25 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 377
# Trainable params: 377
# Non-trainable params: 0
# _________________________________________________________________
# Window 1, covariates ('humidity',): [27.70777718]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 10)                520
# _________________________________________________________________
# dense_27 (Dense)             (None, 16)                176
# _________________________________________________________________
# dense_28 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 985
# Trainable params: 985
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8348/3542491915.py in <module>
#      53             model.summary()
#      54
# ---> 55             model.fit(
#      56                 x                = data[:, :window_size, :],
#      57                 y                = data[:, window_size:, 0],
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1213                 model=self,
#    1214                 steps_per_execution=self._steps_per_execution)
# -> 1215           val_logs = self.evaluate(
#    1216               x=val_x,
#    1217               y=val_y,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1499             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1500               callbacks.on_test_batch_begin(step)
# -> 1501               tmp_logs = self.test_function(iterator)
#    1502               if data_handler.should_sync:
#    1503                 context.async_wait()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     922       # In this case we have not created variables on the first call. So we can
#     923       # run the first trace but we should fail if variables are created.
# --> 924       results = self._stateful_fn(*args, **kwds)
#     925       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     926         raise ValueError("Creating variables on a non-first call to a function"
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3037       (graph_function,
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1961         and executing_eagerly):
#    1962       # No tape is watching; skip to running the function.
# -> 1963       return self._build_call_outputs(self._inference_function.call(
#    1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Fine tuning
# Once we know what model behaves the best, we try to explode this configuration.

# %%
# We will use early stopping to select the best model
callback = tf.keras.callbacks.EarlyStopping(
    monitor              = 'val_loss',
    patience             = 30,
    restore_best_weights = True
)

# percentage of train samples
train_pct = 0.9

# We will store all the results in a data frame
results = pd.DataFrame(
    {i: [None]*4 for i in [4, 8, 16, 32]}
)

# dense configurations:
dense_combination_config = [[16], [16, 16], [32], [32, 32]]

window_size = 15

# we do not need to create the data in a loop:
windows = {i: generate_windows(df_summer_normalized[i], window_size, 1)
                for i in ["radon", "state"] }
data    = mix_data(windows)
N_total = data.shape[0]
test    = data[int(train_pct * N_total):, :, :]
data    = data[:int(train_pct * N_total), :, :]

for idx, dense_config in enumerate(dense_combination_config):
    for num_hidden_units in [4, 8, 16, 32]:
        
        model = tf.keras.models.Sequential(
            [
                tf.keras.layers.InputLayer((window_size, len(windows.keys()))),
                tf.keras.layers.LSTM(num_hidden_units),
                *[tf.keras.layers.Dense(i, activation = "relu") for i in dense_config],
                tf.keras.layers.Dense(1)
            ],
        )

        model.compile(
            loss = tf.keras.losses.MeanSquaredError(),
            metrics = tf.keras.metrics.RootMeanSquaredError(),
            optimizer = tf.keras.optimizers.RMSprop()
        )

        model.summary()

        model.fit(
            x                = data[:, :window_size, :],
            y                = data[:, window_size:, 0],
            epochs           = 1_000,
            shuffle          = False,
            validation_split = 0.2, 
            callbacks        = [callback,],
            verbose          = 0,
        )

        # Model trained

        # Now compute the test predictions and add them to the data frame
        rescale    = lambda x: x * (summer_max.radon - summer_min.radon) + summer_min.radon
        prediction = rescale( model.predict(test[:, :window_size, :]) )
        real       = rescale( test[:, window_size:, 0] )

        rmse_test = ( sum((prediction - real) ** 2) / len(prediction) ) ** (1/2)
        results[num_hidden_units][idx] = rmse_test 
        print(f"Config {idx} with {num_hidden_units} hidden units -> {rmse_test}")
        print("*" * 100, "\n"*2)
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_24 (LSTM)               (None, 4)                 112
# _________________________________________________________________
# dense_78 (Dense)             (None, 16)                80
# _________________________________________________________________
# dense_79 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 209
# Trainable params: 209
# Non-trainable params: 0
# _________________________________________________________________
